# %%
from pyxnat import Interface

# %%
interface = Interface(
              server='https://cnda.wustl.edu',
              user='iturriamedina',
              password='sheresada',
              cachedir='/tmp'
              )

# %%
project = interface.select.project('YIM_EL_2018').insert()

# %%
interface.select('/projects').get()
# Out:
# ['0137',
#  '155-CL-031',
#  '191622-094',
#  '191622-094-00',
#  'AC-058B201',
#  'ACRIN',
#  'ACRIN6677',
#  'ACRIN6682',
#  'ACRIN6684',
#  'ACRIN6685',
#  'ADEM',
#  'ADNI',
#  'ADNI2',
#  'ADNI-GO',
#  'ADNI_Harmonize',
#  'ADNI_PROC',
#  'ADRC',
#  'ADRCCAP',
#  'ADRCCAPII',
#  'ADRCFTD',
#  'ADVL0815',
#  'ARRAY-162-111',
#  'ART',
#  'ASLstroke',
#  'ASLstrokeCONTROL',
#  'BA_HIV',
#  'BenzingerControl',
#  'BMS747158-201',
#  'BMTCTN0601',
#  'CANTU',
#  'CCCVD',
#  'CCIR_00021',
#  'CCIR_00022',
#  'CCIR_00024',
#  'CCIR_00025',
#  'CCIR_00026',
#  'CCIR_00027',
#  'CCIR_00028',
#  'CCIR_00029',
#  'CCIR_00030',
#  'CCIR_00031',
#  'CCIR_00032',
#  'CCIR_00045',
#  'CCIR_00054',
#  'CCIR_00056',
#  'CCIR_00064',
#  'CCIR_00067',
#  'CCIR_00072',
#  'CCIR_00076',
#  'CCIR_00077',
#  'CCIR_00078',
#  'CCIR_00081',
#  'CCIR_00082',
#  'CCIR_00083',
#  'CCIR_00086',
#  'CCIR_00087',
#  'CCIR_00091',
#  'CCIR_00094',
#  'CCIR_00096',
#  'CCIR_00100',
#  'CCIR_00102',
# ...
