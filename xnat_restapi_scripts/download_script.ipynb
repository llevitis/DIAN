# %%
from pyxnat import Interface

# %%
xnat = Interface(
              server='https://cnda.wustl.edu',
              user='iturriamedina',
              password='sheresada',
              cachedir='/tmp'
              )

# %%
subjects = xnat.select('/projects/DIANDF11/subjects').get()

# %%
subjects[0:5]
# Out:
# ['CNDA_S26355', 'CNDA_S26356', 'CNDA_S26357', 'CNDA_S26358', 'CNDA_S26414']

# %%
xnat.select('/projects/DIANDF11/subjects/CNDA_S26355/experiments').get()
# Out:
# ['CNDA_E101573',
#  'CNDA_E101575',
#  'CNDA_E109468',
#  'CNDA_E109491',
#  'CNDA_E112287',
#  'CNDA_E112292']

# %%
xnat.select('/projects/DIANDF11/subjects/CNDA_S26355/experiments/CNDA_E101573').get()
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<xnat:MRSession ID="CNDA_E101573" project="DIANDF" visit_id="v00" label="ZJVKU1_v00_mr" session_type="DIANDF" modality="MR" UID="1.3.12.2.1107.5.2.32.35248.30000009012615114486600000022" xmlns:visit="http://nrg.wustl.edu/visit" xmlns:cnda_ext="http://nrg.wustl.edu/cnda_ext" xmlns:ghf="http://nrg.wustl.edu/ghf" xmlns:kblack="http://nrg.wustl.edu/wu_kblack" xmlns:dian="http://nrg.wustl.edu/dian" xmlns:rad="http://nrg.wustl.edu/rad" xmlns:scr="http://nrg.wustl.edu/scr" xmlns:xnat_a="http://nrg.wustl.edu/xnat_assessments" xmlns:pipe="http://nrg.wustl.edu/pipe" xmlns:bcl="http://nrg.wustl.edu/bcl" xmlns:cog="http://nrg.wustl.edu/cog" xmlns:cnda="http://nrg.wustl.edu/cnda" xmlns:srs="http://nrg.wustl.edu/srs" xmlns:prov="http://www.nbirn.net/prov" xmlns:genetics="http://nrg.wustl.edu/genetics" xmlns:sf="http://nrg.wustl.edu/sf" xmlns:cbat="http://nrg.wustl.edu/cbat" xmlns:ls2="http://nrg.wustl.edu/ls2" xmlns:fs="http://nrg.wustl.edu/fs" xmlns:behavi
# ...

# %%
subject = sandbox.subjects['bla_subject']

# %%
xnat.inspect.datatypes('xnat:subjectData')
# Out:
# ['xnat:subjectData/SUBJECT_ID',
#  'xnat:subjectData/INSERT_DATE',
#  'xnat:subjectData/INSERT_USER',
#  'xnat:subjectData/GENDER_TEXT',
#  'xnat:subjectData/HANDEDNESS_TEXT',
#  'xnat:subjectData/YOB',
#  'xnat:subjectData/EDUC',
#  'xnat:subjectData/SES',
#  'xnat:subjectData/MR_COUNT',
#  'xnat:subjectData/PET_COUNT',
#  'xnat:subjectData/CT_COUNT',
#  'xnat:subjectData/US_COUNT',
#  'xnat:subjectData/INVEST',
#  'xnat:subjectData/PROJECTS',
#  'xnat:subjectData/PROJECT',
#  'xnat:subjectData/GEST',
#  'xnat:subjectData/POST_MENST',
#  'xnat:subjectData/BIRTH_W',
#  'xnat:subjectData/SUBJECT_LABEL',
#  'xnat:subjectData/ADD_IDS',
#  'xnat:subjectData/CLN_COUNT',
#  'xnat:subjectData/PSY_COUNT',
#  'xnat:subjectData/BLD_COUNT',
#  'xnat:subjectData/FAMILY',
#  'xnat:subjectData/MAP',
#  'xnat:subjectData/CSF_COUNT',
#  'xnat:subjectData/RACE',
#  'xnat:subjectData/ETHNICITY',
#  'xnat:subjectData/SUB_GROUP',
#  'xnat:subjectData/XNAT_COL_SUBJECTDATALABEL',
# ...

# %%
test_subject.resources.im_class
# Out:
# pyxnat.core.resources.Subject

# %%
subjects = xnat.select('/projects/DIANDF11/subjects/')

# %%
subjects.experiments.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-77cef5c3323a> in <module>()
# ----> 1 DIANDF11.description
#
# AttributeError: 'Project' object has no attribute 'description'
